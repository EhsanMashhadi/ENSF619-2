# %% [markdown]
# # Summary of chapter 3
# To run the code please read the README.md file

# %% [markdown]
# # Autoencoder
#
# In this chapter, we learn what is autoencoder. Auto-encoder is a complex mathematical model which trains on unlabeled as well as unclassified data and is used to map the input data to another compressed feature representation and from that feature representation reconstructing back the input data. An autoencoder is composed of an encoder(An encoder network that compresses high-dimensional input data into a lower-dimensional representation vector) and a decoder(A decoder network that decompresses a given representation vector back to the original domain) sub-models.
# There is a nice story in this book. Suppose there are two brothers Mr.N Coder and Mr.D Coder and they have an exhibition.
# When a new painting arrives for display, Mr. N. Coder simply chooses a point on the wall to represent the painting, places a marker at this point, then throws the original artwork away. When a customer requests to see the painting, Mr. D. Coder attempts to re-create the artwork using just the coordinates of the relevant marker on the wall.
# Mr. N. Coder and Mr. D. Coder are using representation vectors inside a two-dimensional latent space (the wall) to encode each image.
# <img src="./img/compressed_representation.PNG">

# %% [markdown]
# ## Set parameters

# %%
import os
import numpy as np
from utils.loaders import load_mnist
from models.AE import Autoencoder

# %%
# run params
SECTION = 'vae'
RUN_ID = '0001'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

MODE =  'build' #'load' #

# %% [markdown]
# ## Load the data
# MNIST contains a collection of 70,000, 28 x 28 images of handwritten digits from 0 to 9.

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## How is the architecture of this autoencoder?
#
# Its architecture is a convolutional autoencoder.The encoder is a standard convolution and the decoder is transposed convolution

# %% [markdown]
# ### what is the task of a convolutional auto-encoder
# A convolutional auto-encoder is tasked with recreating its input image, after passing intermediate results through a ‘bottleneck’ of a limited size. Uses of auto-encoders include compression, noise removal, colorization, and in-painting. Success depends on being able to learn dataset-specific compression in the convolution kernels and dataset-specific decompression in the transposed convolution kernels.
# <img src="./img/convloutional_representation.PNG">

# %%
AE = Autoencoder(
    #Size of the vocabulary
    input_dim = (28,28,1)
    
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    #two-dimensional latent space
    , z_dim = 2
)

if MODE == 'build':
    AE.save(RUN_FOLDER)
else:
    AE.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
#There are 3 steps to encoding in AE.py
#Defining the input to the encoder (the image).
#Stacking convolutional layers sequentially on top of each other.
#Flattening the last convolutional layer to a vector to the 2D latent space.
#Also the model that defines the encoder is the Keras —a model that takes an input image and encodes it into the 2D latent space.
AE.encoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# encoder_input (InputLayer)   (None, 28, 28, 1)         0
# _________________________________________________________________
# encoder_conv_0 (Conv2D)      (None, 28, 28, 32)        320
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 28, 28, 32)        0
# _________________________________________________________________
# encoder_conv_1 (Conv2D)      (None, 14, 14, 64)        18496
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 14, 14, 64)        0
# _________________________________________________________________
# encoder_conv_2 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# encoder_conv_3 (Conv2D)      (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# encoder_output (Dense)       (None, 2)                 6274
# =================================================================
# Total params: 98,946
# Trainable params: 98,946
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## what is Transposing Convolutions?
# transposing convolutions is changing the order of the dimensions in the convolution operation matrix, which has some interesting effects and leads to different behaviors to the regular convolutions.

# %%
#There are 4 steps to decoding in AE.py
#Defining the input to the decoder (the point in the latent space).
#Connecting the input to a Dense layer.
#Reshapping this vector into a tensor that can be fed as input into the first convolutional transpose layer
#Stack convolutional transpose layers on top of each other.
#Also, the model that defines the decoder is the Keras—a model that takes a point in the latent space and decodes it into the original image domain.
AE.decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   (None, 2)                 0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_2 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Train the autoencoder

# %%
LEARNING_RATE = 0.0005
BATCH_SIZE = 32
INITIAL_EPOCH = 0

# %%
AE.compile(LEARNING_RATE)

# %%
#the loss function is root mean squared error (RMSE) 
AE.train(     
    x_train[:1000]
    , batch_size = BATCH_SIZE
    , epochs = 200
    , run_folder = RUN_FOLDER
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# W1130 18:58:45.937368 36308 deprecation_wrapper.py:119] From D:\anaconda3\envs\generative\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# W1130 18:58:46.091837 36308 deprecation_wrapper.py:119] From D:\anaconda3\envs\generative\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
# Epoch 1/200
#  224/1000 [=====>........................] - ETA: 7s - loss: 0.2291
# D:\anaconda3\envs\generative\lib\site-packages\keras\callbacks.py:122: UserWarning: Method on_batch_end() is slow compared to the batch update (0.169973). Check your callbacks.
#   % delta_t_median)
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.1807A: 1s - loss
#
# Epoch 00001: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 2/200
# 1000/1000 [==============================] - 1s 985us/step - loss: 0.0867
#
# Epoch 00002: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 3/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0680
#
# Epoch 00003: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 4/200
# 1000/1000 [==============================] - 1s 961us/step - loss: 0.0644
#
# Epoch 00004: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 5/200
# 1000/1000 [==============================] - 1s 961us/step - loss: 0.0602
#
# Epoch 00005: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 6/200
# 1000/1000 [==============================] - 1s 970us/step - loss: 0.0580
#
# Epoch 00006: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 7/200
# 1000/1000 [==============================] - 1s 957us/step - loss: 0.0563
#
# Epoch 00007: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 8/200
# 1000/1000 [==============================] - 1s 980us/step - loss: 0.0552
#
# Epoch 00008: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 9/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0543
#
# Epoch 00009: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 10/200
# 1000/1000 [==============================] - 1s 968us/step - loss: 0.0537
#
# Epoch 00010: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 11/200
# 1000/1000 [==============================] - 1s 957us/step - loss: 0.0531
#
# Epoch 00011: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 12/200
# 1000/1000 [==============================] - 1s 985us/step - loss: 0.0526
#
# Epoch 00012: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 13/200
# 1000/1000 [==============================] - 1s 957us/step - loss: 0.0521
#
# Epoch 00013: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 14/200
# 1000/1000 [==============================] - 1s 947us/step - loss: 0.0517
#
# Epoch 00014: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 15/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0515
#
# Epoch 00015: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 16/200
# 1000/1000 [==============================] - 1s 934us/step - loss: 0.0512
#
# Epoch 00016: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 17/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0506
#
# Epoch 00017: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 18/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0503
#
# Epoch 00018: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 19/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0501
#
# Epoch 00019: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 20/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0498
#
# Epoch 00020: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 21/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0495
#
# Epoch 00021: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 22/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0493
#
# Epoch 00022: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 23/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0491
#
# Epoch 00023: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 24/200
# 1000/1000 [==============================] - 1s 951us/step - loss: 0.0486
#
# Epoch 00024: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 25/200
# 1000/1000 [==============================] - 1s 942us/step - loss: 0.0486
#
# Epoch 00025: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 26/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0482
#
# Epoch 00026: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 27/200
# 1000/1000 [==============================] - 1s 999us/step - loss: 0.0480
#
# Epoch 00027: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 28/200
# 1000/1000 [==============================] - 1s 952us/step - loss: 0.0480
#
# Epoch 00028: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 29/200
# 1000/1000 [==============================] - 1s 950us/step - loss: 0.0476
#
# Epoch 00029: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 30/200
# 1000/1000 [==============================] - 1s 957us/step - loss: 0.0473
#
# Epoch 00030: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 31/200
# 1000/1000 [==============================] - 1s 995us/step - loss: 0.0471
#
# Epoch 00031: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 32/200
# 1000/1000 [==============================] - 1s 931us/step - loss: 0.0469
#
# Epoch 00032: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 33/200
# 1000/1000 [==============================] - 1s 980us/step - loss: 0.0467
#
# Epoch 00033: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 34/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0469
#
# Epoch 00034: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 35/200
# 1000/1000 [==============================] - 1s 999us/step - loss: 0.0464
#
# Epoch 00035: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 36/200
# 1000/1000 [==============================] - 1s 934us/step - loss: 0.0463
#
# Epoch 00036: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 37/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0461
#
# Epoch 00037: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 38/200
# 1000/1000 [==============================] - 1s 994us/step - loss: 0.0459 0s - loss: 0.04
#
# Epoch 00038: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 39/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0457
#
# Epoch 00039: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 40/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0456
#
# Epoch 00040: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 41/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0452
#
# Epoch 00041: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 42/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0453
#
# Epoch 00042: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 43/200
# 1000/1000 [==============================] - 1s 965us/step - loss: 0.0454 0s - loss: 0.0
#
# Epoch 00043: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 44/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0448A: 0s - loss: 0
#
# Epoch 00044: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 45/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0446
#
# Epoch 00045: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 46/200
# 1000/1000 [==============================] - 1s 944us/step - loss: 0.0445
#
# Epoch 00046: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 47/200
# 1000/1000 [==============================] - 1s 984us/step - loss: 0.0441
#
# Epoch 00047: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 48/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0442
#
# Epoch 00048: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 49/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0437
#
# Epoch 00049: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 50/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0436
#
# Epoch 00050: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 51/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0437
#
# Epoch 00051: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 52/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0434
#
# Epoch 00052: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 53/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0433
#
# Epoch 00053: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 54/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0432
#
# Epoch 00054: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 55/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0431
#
# Epoch 00055: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 56/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0433
#
# Epoch 00056: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 57/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0432
#
# Epoch 00057: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 58/200
# 1000/1000 [==============================] - 1s 950us/step - loss: 0.0424
#
# Epoch 00058: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 59/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0422
#
# Epoch 00059: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 60/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0422
#
# Epoch 00060: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 61/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0422
#
# Epoch 00061: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 62/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0422
#
# Epoch 00062: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 63/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0421
#
# Epoch 00063: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 64/200
# 1000/1000 [==============================] - 1s 987us/step - loss: 0.0419
#
# Epoch 00064: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 65/200
# 1000/1000 [==============================] - 1s 997us/step - loss: 0.0419
#
# Epoch 00065: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 66/200
# 1000/1000 [==============================] - 1s 954us/step - loss: 0.0419
#
# Epoch 00066: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 67/200
# 1000/1000 [==============================] - 1s 986us/step - loss: 0.0418
#
# Epoch 00067: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 68/200
# 1000/1000 [==============================] - 1s 993us/step - loss: 0.0413
#
# Epoch 00068: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 69/200
# 1000/1000 [==============================] - 1s 959us/step - loss: 0.0414
#
# Epoch 00069: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 70/200
# 1000/1000 [==============================] - ETA: 0s - loss: 0.040 - 1s 1ms/step - loss: 0.0411
#
# Epoch 00070: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 71/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0408
#
# Epoch 00071: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 72/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0415
#
# Epoch 00072: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 73/200
# 1000/1000 [==============================] - 1s 986us/step - loss: 0.0409
#
# Epoch 00073: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 74/200
# 1000/1000 [==============================] - 1s 977us/step - loss: 0.0405
#
# Epoch 00074: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 75/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0403
#
# Epoch 00075: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 76/200
# 1000/1000 [==============================] - 1s 973us/step - loss: 0.0403
#
# Epoch 00076: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 77/200
# 1000/1000 [==============================] - 1s 958us/step - loss: 0.0406
#
# Epoch 00077: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 78/200
# 1000/1000 [==============================] - 1s 957us/step - loss: 0.0402
#
# Epoch 00078: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 79/200
# 1000/1000 [==============================] - 1s 942us/step - loss: 0.0402
#
# Epoch 00079: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 80/200
# 1000/1000 [==============================] - 1s 954us/step - loss: 0.0402 0s - loss: 0.0
#
# Epoch 00080: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 81/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0401
#
# Epoch 00081: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 82/200
# 1000/1000 [==============================] - 1s 951us/step - loss: 0.0399
#
# Epoch 00082: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 83/200
# 1000/1000 [==============================] - 1s 975us/step - loss: 0.0401
#
# Epoch 00083: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 84/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0397
#
# Epoch 00084: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 85/200
# 1000/1000 [==============================] - 1s 994us/step - loss: 0.0395 0s - loss:
#
# Epoch 00085: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 86/200
# 1000/1000 [==============================] - 1s 963us/step - loss: 0.0393
#
# Epoch 00086: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 87/200
# 1000/1000 [==============================] - 1s 984us/step - loss: 0.0392
#
# Epoch 00087: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 88/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0390
#
# Epoch 00088: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 89/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0394
#
# Epoch 00089: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 90/200
# 1000/1000 [==============================] - 1s 999us/step - loss: 0.0391
#
# Epoch 00090: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 91/200
# 1000/1000 [==============================] - 1s 979us/step - loss: 0.0390
#
# Epoch 00091: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 92/200
# 1000/1000 [==============================] - 1s 910us/step - loss: 0.0392
#
# Epoch 00092: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 93/200
# 1000/1000 [==============================] - 1s 944us/step - loss: 0.0390
#
# Epoch 00093: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 94/200
# 1000/1000 [==============================] - 1s 920us/step - loss: 0.0387
#
# Epoch 00094: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 95/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0389
#
# Epoch 00095: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 96/200
# 1000/1000 [==============================] - 1s 925us/step - loss: 0.0395 0s - loss: 0.
#
# Epoch 00096: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 97/200
# 1000/1000 [==============================] - 1s 920us/step - loss: 0.0388
#
# Epoch 00097: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 98/200
# 1000/1000 [==============================] - 1s 925us/step - loss: 0.0386
#
# Epoch 00098: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 99/200
# 1000/1000 [==============================] - 1s 965us/step - loss: 0.0386
#
# Epoch 00099: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 100/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0388
#
# Epoch 00100: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 101/200
# 1000/1000 [==============================] - 1s 959us/step - loss: 0.0387
#
# Epoch 00101: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 102/200
# 1000/1000 [==============================] - 1s 912us/step - loss: 0.0381
#
# Epoch 00102: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 103/200
# 1000/1000 [==============================] - 1s 940us/step - loss: 0.0383
#
# Epoch 00103: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 104/200
# 1000/1000 [==============================] - 1s 910us/step - loss: 0.0383
#
# Epoch 00104: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 105/200
# 1000/1000 [==============================] - 1s 950us/step - loss: 0.0381
#
# Epoch 00105: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 106/200
# 1000/1000 [==============================] - 1s 955us/step - loss: 0.0380
#
# Epoch 00106: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 107/200
# 1000/1000 [==============================] - 1s 902us/step - loss: 0.0378
#
# Epoch 00107: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 108/200
# 1000/1000 [==============================] - 1s 891us/step - loss: 0.0377
#
# Epoch 00108: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 109/200
# 1000/1000 [==============================] - 1s 940us/step - loss: 0.0376
#
# Epoch 00109: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 110/200
# 1000/1000 [==============================] - 1s 905us/step - loss: 0.0375
#
# Epoch 00110: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 111/200
# 1000/1000 [==============================] - 1s 965us/step - loss: 0.0377
#
# Epoch 00111: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 112/200
# 1000/1000 [==============================] - 1s 964us/step - loss: 0.0379 0s - loss:
#
# Epoch 00112: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 113/200
# 1000/1000 [==============================] - 1s 937us/step - loss: 0.0376
#
# Epoch 00113: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 114/200
# 1000/1000 [==============================] - 1s 920us/step - loss: 0.0373
#
# Epoch 00114: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 115/200
# 1000/1000 [==============================] - 1s 980us/step - loss: 0.0378
#
# Epoch 00115: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 116/200
# 1000/1000 [==============================] - 1s 975us/step - loss: 0.0379
#
# Epoch 00116: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 117/200
# 1000/1000 [==============================] - 1s 970us/step - loss: 0.0377
#
# Epoch 00117: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 118/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0376
#
# Epoch 00118: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 119/200
# 1000/1000 [==============================] - 1s 930us/step - loss: 0.0376
#
# Epoch 00119: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 120/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0375
#
# Epoch 00120: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 121/200
# 1000/1000 [==============================] - 1s 950us/step - loss: 0.0372
#
# Epoch 00121: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 122/200
# 1000/1000 [==============================] - 1s 934us/step - loss: 0.0374
#
# Epoch 00122: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 123/200
# 1000/1000 [==============================] - 1s 980us/step - loss: 0.0374
#
# Epoch 00123: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 124/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0376
#
# Epoch 00124: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 125/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0372
#
# Epoch 00125: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 126/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0371
#
# Epoch 00126: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 127/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0369
#
# Epoch 00127: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 128/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0369
#
# Epoch 00128: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 129/200
# 1000/1000 [==============================] - 1s 990us/step - loss: 0.0370
#
# Epoch 00129: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 130/200
# 1000/1000 [==============================] - 1s 986us/step - loss: 0.0372
#
# Epoch 00130: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 131/200
# 1000/1000 [==============================] - 1s 969us/step - loss: 0.0369
#
# Epoch 00131: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 132/200
# 1000/1000 [==============================] - 1s 970us/step - loss: 0.0366
#
# Epoch 00132: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 133/200
# 1000/1000 [==============================] - 1s 969us/step - loss: 0.0365
#
# Epoch 00133: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 134/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0365
#
# Epoch 00134: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 135/200
# 1000/1000 [==============================] - 1s 900us/step - loss: 0.0366
#
# Epoch 00135: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 136/200
# 1000/1000 [==============================] - 1s 917us/step - loss: 0.0366
#
# Epoch 00136: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 137/200
# 1000/1000 [==============================] - 1s 957us/step - loss: 0.0367
#
# Epoch 00137: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 138/200
# 1000/1000 [==============================] - 1s 935us/step - loss: 0.0364
#
# Epoch 00138: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 139/200
# 1000/1000 [==============================] - 1s 940us/step - loss: 0.0365
#
# Epoch 00139: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 140/200
# 1000/1000 [==============================] - 1s 912us/step - loss: 0.0365
#
# Epoch 00140: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 141/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0366 0s - lo - ETA: 0s - loss: 0.036
#
# Epoch 00141: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 142/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0363
#
# Epoch 00142: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 143/200
# 1000/1000 [==============================] - 1s 961us/step - loss: 0.0369
#
# Epoch 00143: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 144/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0366
#
# Epoch 00144: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 145/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0362
#
# Epoch 00145: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 146/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0362
#
# Epoch 00146: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 147/200
# 1000/1000 [==============================] - 1s 982us/step - loss: 0.0361
#
# Epoch 00147: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 148/200
# 1000/1000 [==============================] - 1s 910us/step - loss: 0.0361
#
# Epoch 00148: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 149/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0361
#
# Epoch 00149: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 150/200
# 1000/1000 [==============================] - 1s 1000us/step - loss: 0.0359
#
# Epoch 00150: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 151/200
# 1000/1000 [==============================] - 1s 991us/step - loss: 0.0359
#
# Epoch 00151: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 152/200
# 1000/1000 [==============================] - 1s 932us/step - loss: 0.0363
#
# Epoch 00152: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 153/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0360
#
# Epoch 00153: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 154/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0358
#
# Epoch 00154: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 155/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0360
#
# Epoch 00155: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 156/200
# 1000/1000 [==============================] - 1s 970us/step - loss: 0.0357
#
# Epoch 00156: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 157/200
# 1000/1000 [==============================] - 1s 972us/step - loss: 0.0365
#
# Epoch 00157: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 158/200
# 1000/1000 [==============================] - 1s 950us/step - loss: 0.0359 0s - loss: 0.
#
# Epoch 00158: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 159/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0357 0s - l
#
# Epoch 00159: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 160/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0354
#
# Epoch 00160: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 161/200
# 1000/1000 [==============================] - 1s 965us/step - loss: 0.0357
#
# Epoch 00161: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 162/200
# 1000/1000 [==============================] - 1s 944us/step - loss: 0.0358
#
# Epoch 00162: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 163/200
# 1000/1000 [==============================] - 1s 944us/step - loss: 0.0356
#
# Epoch 00163: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 164/200
# 1000/1000 [==============================] - 1s 965us/step - loss: 0.0357
#
# Epoch 00164: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 165/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0358
#
# Epoch 00165: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 166/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0353
#
# Epoch 00166: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 167/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0356
#
# Epoch 00167: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 168/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0355
#
# Epoch 00168: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 169/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0352
#
# Epoch 00169: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 170/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0351
#
# Epoch 00170: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 171/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0353
#
# Epoch 00171: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 172/200
# 1000/1000 [==============================] - 1s 970us/step - loss: 0.0354
#
# Epoch 00172: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 173/200
# 1000/1000 [==============================] - 1s 943us/step - loss: 0.0353
#
# Epoch 00173: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 174/200
# 1000/1000 [==============================] - 1s 935us/step - loss: 0.0356
#
# Epoch 00174: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 175/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0352
#
# Epoch 00175: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 176/200
# 1000/1000 [==============================] - 1s 980us/step - loss: 0.0356
#
# Epoch 00176: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 177/200
# 1000/1000 [==============================] - 1s 945us/step - loss: 0.0352
#
# Epoch 00177: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 178/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0353
#
# Epoch 00178: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 179/200
# 1000/1000 [==============================] - 1s 985us/step - loss: 0.0350
#
# Epoch 00179: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 180/200
# 1000/1000 [==============================] - 1s 934us/step - loss: 0.0349
#
# Epoch 00180: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 181/200
# 1000/1000 [==============================] - 1s 925us/step - loss: 0.0349
#
# Epoch 00181: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 182/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0346
#
# Epoch 00182: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 183/200
# 1000/1000 [==============================] - 1s 990us/step - loss: 0.0352
#
# Epoch 00183: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 184/200
# 1000/1000 [==============================] - 1s 935us/step - loss: 0.0351
#
# Epoch 00184: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 185/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0348
#
# Epoch 00185: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 186/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0349
#
# Epoch 00186: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 187/200
# 1000/1000 [==============================] - 1s 944us/step - loss: 0.0347
#
# Epoch 00187: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 188/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0350
#
# Epoch 00188: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 189/200
# 1000/1000 [==============================] - 1s 910us/step - loss: 0.0348
#
# Epoch 00189: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 190/200
# 1000/1000 [==============================] - 1s 999us/step - loss: 0.0346
#
# Epoch 00190: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 191/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0346 0s - lo
#
# Epoch 00191: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 192/200
# 1000/1000 [==============================] - 1s 929us/step - loss: 0.0345
#
# Epoch 00192: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 193/200
# 1000/1000 [==============================] - 1s 960us/step - loss: 0.0349
#
# Epoch 00193: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 194/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0345
#
# Epoch 00194: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 195/200
# 1000/1000 [==============================] - 1s 989us/step - loss: 0.0346
#
# Epoch 00195: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 196/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0344
#
# Epoch 00196: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 197/200
# 1000/1000 [==============================] - 1s 1ms/step - loss: 0.0343
#
# Epoch 00197: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 198/200
# 1000/1000 [==============================] - 1s 997us/step - loss: 0.0346
#
# Epoch 00198: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 199/200
# 1000/1000 [==============================] - 1s 981us/step - loss: 0.0347
#
# Epoch 00199: saving model to run/vae/0001_digits\weights/weights.h5
# Epoch 200/200
# 1000/1000 [==============================] - 1s 965us/step - loss: 0.0347
#
# Epoch 00200: saving model to run/vae/0001_digits\weights/weights.h5

# %% [markdown]
# # Autoencoder Analysis
# The goal is to be able to choose a random point in the latent space, pass this through the decoder, and obtain an image of a digit that looks real.There is 3 problem to do this:
# <ul>
#     <li>it’s not obvious how we should even go about choosing a random point in the latent space.</li>
#     <li>the lack of diversity in the generated images. Ideally, we’d like to obtain a roughly equal spread of digits when sampling randomly from our latent space.But,8 need more space than 1</li>
#     <li>existing large gaps between colors containing few points</li>
# </ul>

# %% [markdown]
# ## imports

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm
from utils.loaders import load_model

# %% [markdown]
# ## Load the model architecture

# %%
AE = load_model(Autoencoder, RUN_FOLDER)

# %% [markdown]
# ## reconstructing original paintings
#
# When a new painting arrives at the exhibition, Mr. N. Coder chooses a point on the wall where he would like to place the marker to represent the artwork, as before.Suppose Mr.N coder has a daughter, Epsilon.She of course takes her father’s opinion into account, so she usually places the marker somewhere near the point that he suggests.Her job is to show the point to Mr.D coder.After training with these simple changes, Mr. N. Coder once again tries his strategy of placing markers on portions of the wall that are empty, so that Mr. D. Coder can regenerate these points as original artwork.But they have to make sure that they have generated images almost like the orginal one and also diverse images.Otherwise they may sell less ticket for the exibition.
#
# In other words,the encoder will take each input image and encode it to two vectors, mu and log_var which together define a multivariate normal distribution in the latent space:
#
# **mu**
# The mean point of the distribution.
#
# **log_var**
# The logarithm of the variance of each dimension.
#
# To encode an image into a specific point z in the latent space, we can sample from this distribution, using the following equation:
#
# **z = mu + sigma * epsilon**
# where
#
# **sigma = exp(log_var / 2)**
# epsilon is a point sampled from the standard normal distribution.
#
# Relating this back to our story, mu represents Mr. N. Coder’s opinion of where the marker should appear on the wall. epsilon is his daughter’s random choice of how far away from mu the marker should be placed, scaled by sigma, Mr. N. Coder’s confidence in the marker’s position.
#
# This means the encoder only needs to map each input to a mean vector and a variance vector and does not need to worry about covariance between dimensions.
#
# Now, since we are sampling a random point from an area around mu, the decoder must ensure that all points in the same neighborhood produce very similar images when decoded, so that the reconstruction loss remains small. This is a very nice property that ensures that even when we choose a point in the latent space that has never been seen by the decoder, it is likely to decode to an image that is well formed.

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
#Mr.N Coder job
z_points = AE.encoder.predict(example_images)
#Mr.D Coder Job(generate paintings like orginal)
reconst_images = AE.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)   
    ax.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    ax.axis('off')
    ax.imshow(img, cmap='gray_r')

# %% [markdown]
# ## Mr N. Coder's wall

# %%
n_to_show = 5000
grid_size = 15
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %% [markdown]
# ### The new generated art exhibition(Mr.D Coder task(reconstructing numbers))

# %%
figsize = 5

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)

grid_size = 10
grid_depth = 3
figsize = 15

x = np.random.uniform(min_x,max_x, size = grid_size * grid_depth)
y = np.random.uniform(min_y,max_y, size = grid_size * grid_depth)
z_grid = np.array(list(zip(x, y)))
reconst = AE.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()
#divesrity of numbers have been shown in different colour(there are 5000 numbers in this plot,each number has been represented by specific color)
plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

# x = norm.ppf(np.linspace(0.05, 0.95, 10))
# y = norm.ppf(np.linspace(0.05, 0.95, 10))
x = np.linspace(min(z_points[:, 0]), max(z_points[:, 0]), grid_size)
y = np.linspace(max(z_points[:, 1]), min(z_points[:, 1]), grid_size)
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = AE.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=5)

#The constructed images that are in the space with no input are vague and also those are in the space with multiple colors(different numbers)
#As you can see the points in a specific color are clear


plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %% [markdown]
# # VAE Training
#
# In machine learning, a variational autoencoder,also known as VAE, is the artificial neural network.Variational autoencoders are meant to compress the input information into a constrained multivariate latent distribution (encoding) to reconstruct it as accurately as possible (decoding). Although this type of model was initially designed for unsupervised learning,its effectiveness has been proven in other domains of machine learning such as semi-supervised learning or supervised learning.
#
# The **encoder** is a neural network. Its input is a datapoint x , its output is a hidden representation z , and it has weights and biases θ. To be concrete, let’s say x is a **28** by **28** -pixel photo of a handwritten number. The encoder ‘encodes’ the data which is **784**-dimensional into a latent (hidden) representation space z , which is much less than **784** dimensions. This is typically referred to as a ‘bottleneck’ because the encoder must learn an efficient compression of the data into this lower-dimensional space. Let’s denote the encoder **qθ(z|x)**. We note that the lower-dimensional space is stochastic: the encoder outputs parameters to **qθ(z|x)**, which is a Gaussian probability density. We can sample from this distribution to get noisy values of the representations z.
#
# The **decoder** is another neural net. Its input is the representation z , it outputs the parameters to the probability distribution of the data, and has weights and biases ϕ . The decoder is denoted by **Pϕ(x|z)** . Running with the handwritten digit example, let’s say the photos are black and white and represent each pixel as 0 or 1 . The probability distribution of a single pixel can be then represented using a Bernoulli distribution. The decoder gets as input the latent representation of a digit z and outputs **784** Bernoulli parameters, one for each of the **784** pixels in the image. The decoder ‘decodes’ the real-valued numbers in z into **784** real-valued numbers between 0 and 1. Information from the original **784** -dimensional vector cannot be perfectly transmitted, because the decoder only has access to a summary of the information (in the form of a less-than- **784** -dimensional vector z). How much information is lost? We measure this using the reconstruction log-likelihood **logPϕ(x|z)** whose units are nats. This measure tells us how effectively the decoder has learned to reconstruct an input image x given its latent representation z .
#
# The loss function of the variational autoencoder is the negative log-likelihood with a regularizer. Because there are no global representations that are shared by all datapoints, we can decompose the loss function into only terms that depend on a single datapoint **l<sub>i</sub>** The total loss is then **∑<sub>i=1</sub><sup>N</sup>** for N total datapoints. The loss function for **l<sub>i</sub>** datapoint **x<sub>i</sub>** is:
#
# <img src="./img/formula1.PNG">
#
# The first term is the reconstruction loss, or expected negative log-likelihood of the i-th datapoint. The expectation is taken with respect to the encoder’s distribution over the representations. This term encourages the decoder to learn to reconstruct the data. If the decoder’s output does not reconstruct the data well, statistically we say that the decoder parameterizes a likelihood distribution that does not place much probability mass on the true data. For example, if our goal is to model black and white images and our model places high probability on there being black spots where there are actually white spots, this will yield the worst possible reconstruction. Poor reconstruction will incur a large cost in this loss function.
#
# The second term is a regularizer that we throw in (we’ll see how it’s derived later). This is the Kullback-Leibler divergence between the encoder’s distribution **qθ(z|x)** and **p(z)** . This divergence measures how much information is lost (in units of nats) when using q to represent p . It is one measure of how close q is to p.
#
# In the variational autoencoder, p is specified as a standard Normal distribution with mean zero and variance one, or **p(z) = Normal(0,1)** . If the encoder outputs representations z that are different than those from a standard normal distribution, it will receive a penalty in the loss. This regularizer term means ‘keep the representations z of each digit sufficiently diverse’. If we didn’t include the regularizer, the encoder could learn to cheat and give each datapoint a representation in a different region of Euclidean space. This is bad, because then two images of the same number (say a 2 written by different people, **2<sub>alice</sub>** and  **2<sub>bob</sub>** ) could end up with very different representations **Z<sub>alice</sub>** , **Z<sub>bob</sub>**  . We want the representation space of z to be meaningful, so we penalize this behavior. This has the effect of keeping similar numbers’ representations close together (e.g. so the representations of the digit two **Z<sub>alice</sub>** , **Z<sub>bob</sub>** , **Z<sub>ali</sub>** remain sufficiently close).
#
# We train the variational autoencoder using gradient descent to optimize the loss with respect to the parameters of the encoder and decoder θ and ϕ . For stochastic gradient descent with step size ρ, the encoder parameters are updated using **θ←θ−ρ<sup>∂θ</sup>/<sub>∂l</sub>** and the decoder is updated similarly.
#
#
#  ### Kullback–Leibler (KL) divergence
#
# KL divergence is a way of measuring how much one probability distribution differs from another. In a VAE, we want to measure how different our normal distribution with parameters mu and log_var is from the standard normal distribution. In this special case, the KL divergence has the closed form:
# <img src="./img/formula2.PNG">
#
# or in mathematical notation:
# <img src="./img/formula3.PNG">
#
# The sum is taken over all the dimensions in the latent space. kl_loss is minimized to 0 when mu = 0 and log_var = 0 for all dimensions. As these two terms start to differ from 0, kl_loss increases.
#
# In summary, the KL divergence term penalizes the network for encoding observations to mu and log_var variables that differ significantly from the parameters of a standard normal distribution, namely mu = 0 and log_var = 0.
#
# Again, relating this back to our story, this term represents Epsilon’s annoyance at having to move the ladder away from the middle of the wall (mu different from 0) and also if Mr. N. Coder’s confidence in the marker position isn’t just right (log_var different from 0), both of which incur a cost.
#
# In the code, the loss function for a VAE is simply the addition of the reconstruction loss and the KL divergence loss term. We weight the reconstruction loss with a term, r_loss_factor, that ensures that it is well balanced with the KL divergence loss. If we weight the reconstruction loss too heavily, the KL loss will not have the desired regulatory effect and we will see the same problems that we experienced with the plain autoencoder. If the weighting term is too small, the KL divergence loss will dominate and the reconstructed images will be poor. This weighting term is one of the parameters to tune when you’re training your VAE.

# %% [markdown]
# ## imports

# %%
from models.VAE import VariationalAutoencoder

# %%
# run params

RUN_ID = '0002'
DATA_NAME = 'digits'
RUN_FOLDER = 'run/{}/'.format(SECTION)
RUN_FOLDER += '_'.join([RUN_ID, DATA_NAME])

if not os.path.exists(RUN_FOLDER):
    os.mkdir(RUN_FOLDER)
    os.mkdir(os.path.join(RUN_FOLDER, 'viz'))
    os.mkdir(os.path.join(RUN_FOLDER, 'images'))
    os.mkdir(os.path.join(RUN_FOLDER, 'weights'))

mode =  'build' #'load' #

# %%
#in the VAE.py
#Instead of connecting the flattened layer directly to the 2D latent space, we connect it to layers mu and log_var
#The Keras model that outputs the values of mu and log_var for a given input image.
#Lambda layer samples a point z in the latent space from the normal distribution defined by the parameters mu and log_var
#The Keras model that defines the encoder—a model that takes an input image and encodes it into the 2D latent space,
#by sampling a point from the normal distribution defined by mu and log_var
vae = VariationalAutoencoder(
    input_dim = (28,28,1)
    , encoder_conv_filters = [32,64,64, 64]
    , encoder_conv_kernel_size = [3,3,3,3]
    , encoder_conv_strides = [1,2,2,1]
    , decoder_conv_t_filters = [64,64,32,1]
    , decoder_conv_t_kernel_size = [3,3,3,3]
    , decoder_conv_t_strides = [1,2,2,1]
    , z_dim = 2
)

if mode == 'build':
    vae.save(RUN_FOLDER)
else:
    vae.load_weights(os.path.join(RUN_FOLDER, 'weights/weights.h5'))

# %%
vae.encoder.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# encoder_conv_0 (Conv2D)         (None, 28, 28, 32)   320         encoder_input[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)      (None, 28, 28, 32)   0           encoder_conv_0[0][0]
# __________________________________________________________________________________________________
# encoder_conv_1 (Conv2D)         (None, 14, 14, 64)   18496       leaky_re_lu_22[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)      (None, 14, 14, 64)   0           encoder_conv_1[0][0]
# __________________________________________________________________________________________________
# encoder_conv_2 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_23[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_2[0][0]
# __________________________________________________________________________________________________
# encoder_conv_3 (Conv2D)         (None, 7, 7, 64)     36928       leaky_re_lu_24[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_25 (LeakyReLU)      (None, 7, 7, 64)     0           encoder_conv_3[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 3136)         0           leaky_re_lu_25[0][0]
# __________________________________________________________________________________________________
# mu (Dense)                      (None, 2)            6274        flatten_4[0][0]
# __________________________________________________________________________________________________
# log_var (Dense)                 (None, 2)            6274        flatten_4[0][0]
# __________________________________________________________________________________________________
# encoder_output (Lambda)         (None, 2)            0           mu[0][0]
#                                                                  log_var[0][0]
# ==================================================================================================
# Total params: 105,220
# Trainable params: 105,220
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
vae.decoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# decoder_input (InputLayer)   (None, 2)                 0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3136)              9408
# _________________________________________________________________
# reshape_4 (Reshape)          (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_0 (Conv2DTran (None, 7, 7, 64)          36928
# _________________________________________________________________
# leaky_re_lu_26 (LeakyReLU)   (None, 7, 7, 64)          0
# _________________________________________________________________
# decoder_conv_t_1 (Conv2DTran (None, 14, 14, 64)        36928
# _________________________________________________________________
# leaky_re_lu_27 (LeakyReLU)   (None, 14, 14, 64)        0
# _________________________________________________________________
# decoder_conv_t_2 (Conv2DTran (None, 28, 28, 32)        18464
# _________________________________________________________________
# leaky_re_lu_28 (LeakyReLU)   (None, 28, 28, 32)        0
# _________________________________________________________________
# decoder_conv_t_3 (Conv2DTran (None, 28, 28, 1)         289
# _________________________________________________________________
# activation_4 (Activation)    (None, 28, 28, 1)         0
# =================================================================
# Total params: 102,017
# Trainable params: 102,017
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## training

# %%
LEARNING_RATE = 0.0005
R_LOSS_FACTOR = 1000

# %%
vae.compile(LEARNING_RATE, R_LOSS_FACTOR)

# %%
BATCH_SIZE = 32
EPOCHS = 200
PRINT_EVERY_N_BATCHES = 100
INITIAL_EPOCH = 0

# %%
vae.train(     
    x_train
    , batch_size = BATCH_SIZE
    , epochs = EPOCHS
    , run_folder = RUN_FOLDER
    , print_every_n_batches = PRINT_EVERY_N_BATCHES
    , initial_epoch = INITIAL_EPOCH
)
# Out:
# W1120 21:19:48.705870 34904 deprecation_wrapper.py:119] From D:\anaconda3\envs\generative\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/200
# 60000/60000 [==============================] - 99s 2ms/step - loss: 58.5893 - vae_r_loss: 55.3527 - vae_kl_loss: 3.2366
#
# Epoch 00001: saving model to run/vae/0002_digits\weights/weights-001-58.59.h5
#
# Epoch 00001: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 2/200
# 60000/60000 [==============================] - 97s 2ms/step - loss: 51.6628 - vae_r_loss: 47.6434 - vae_kl_loss: 4.0194
#
# Epoch 00002: saving model to run/vae/0002_digits\weights/weights-002-51.66.h5
#
# Epoch 00002: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 3/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 49.9338 - vae_r_loss: 45.5642 - vae_kl_loss: 4.3696
#
# Epoch 00003: saving model to run/vae/0002_digits\weights/weights-003-49.93.h5
#
# Epoch 00003: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 4/200
# 60000/60000 [==============================] - 99s 2ms/step - loss: 49.0042 - vae_r_loss: 44.4690 - vae_kl_loss: 4.5352
#
# Epoch 00004: saving model to run/vae/0002_digits\weights/weights-004-49.00.h5
#
# Epoch 00004: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 5/200
# 60000/60000 [==============================] - 96s 2ms/step - loss: 48.4043 - vae_r_loss: 43.7636 - vae_kl_loss: 4.6407
#
# Epoch 00005: saving model to run/vae/0002_digits\weights/weights-005-48.40.h5
#
# Epoch 00005: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 6/200
# 60000/60000 [==============================] - 95s 2ms/step - loss: 47.9603 - vae_r_loss: 43.2365 - vae_kl_loss: 4.7238
#
# Epoch 00006: saving model to run/vae/0002_digits\weights/weights-006-47.96.h5
#
# Epoch 00006: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 7/200
# 60000/60000 [==============================] - 96s 2ms/step - loss: 47.6402 - vae_r_loss: 42.8633 - vae_kl_loss: 4.7770
#
# Epoch 00007: saving model to run/vae/0002_digits\weights/weights-007-47.64.h5
#
# Epoch 00007: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 8/200
# 60000/60000 [==============================] - 104s 2ms/step - loss: 47.3401 - vae_r_loss: 42.5169 - vae_kl_loss: 4.8232
#
# Epoch 00008: saving model to run/vae/0002_digits\weights/weights-008-47.34.h5
#
# Epoch 00008: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 9/200
# 60000/60000 [==============================] - 99s 2ms/step - loss: 47.1671 - vae_r_loss: 42.3015 - vae_kl_loss: 4.8656
#
# Epoch 00009: saving model to run/vae/0002_digits\weights/weights-009-47.17.h5
#
# Epoch 00009: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 10/200
# 60000/60000 [==============================] - 99s 2ms/step - loss: 46.9780 - vae_r_loss: 42.0840 - vae_kl_loss: 4.8940
#
# Epoch 00010: saving model to run/vae/0002_digits\weights/weights-010-46.98.h5
#
# Epoch 00010: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 11/200
# 60000/60000 [==============================] - 98s 2ms/step - loss: 46.7759 - vae_r_loss: 41.8583 - vae_kl_loss: 4.9176
#
# Epoch 00011: saving model to run/vae/0002_digits\weights/weights-011-46.78.h5
#
# Epoch 00011: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 12/200
# 60000/60000 [==============================] - 101s 2ms/step - loss: 46.6238 - vae_r_loss: 41.6715 - vae_kl_loss: 4.9523
#
# Epoch 00012: saving model to run/vae/0002_digits\weights/weights-012-46.62.h5
#
# Epoch 00012: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 13/200
# 60000/60000 [==============================] - 102s 2ms/step - loss: 46.4903 - vae_r_loss: 41.5192 - vae_kl_loss: 4.9710
#
# Epoch 00013: saving model to run/vae/0002_digits\weights/weights-013-46.49.h5
#
# Epoch 00013: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 14/200
# 60000/60000 [==============================] - 104s 2ms/step - loss: 46.3805 - vae_r_loss: 41.3885 - vae_kl_loss: 4.9920
#
# Epoch 00014: saving model to run/vae/0002_digits\weights/weights-014-46.38.h5
#
# Epoch 00014: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 15/200
# 60000/60000 [==============================] - 103s 2ms/step - loss: 46.2666 - vae_r_loss: 41.2644 - vae_kl_loss: 5.0021
#
# Epoch 00015: saving model to run/vae/0002_digits\weights/weights-015-46.27.h5
#
# Epoch 00015: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 16/200
# 60000/60000 [==============================] - 104s 2ms/step - loss: 46.1777 - vae_r_loss: 41.1520 - vae_kl_loss: 5.0257
#
# Epoch 00016: saving model to run/vae/0002_digits\weights/weights-016-46.18.h5
#
# Epoch 00016: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 17/200
# 60000/60000 [==============================] - 99s 2ms/step - loss: 46.0341 - vae_r_loss: 41.0051 - vae_kl_loss: 5.0290
#
# Epoch 00017: saving model to run/vae/0002_digits\weights/weights-017-46.03.h5
#
# Epoch 00017: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 18/200
# 60000/60000 [==============================] - 74s 1ms/step - loss: 46.0014 - vae_r_loss: 40.9462 - vae_kl_loss: 5.0552
#
# Epoch 00018: saving model to run/vae/0002_digits\weights/weights-018-46.00.h5
#
# Epoch 00018: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 19/200
# 60000/60000 [==============================] - 55s 912us/step - loss: 45.8694 - vae_r_loss: 40.8183 - vae_kl_loss: 5.0510
#
# Epoch 00019: saving model to run/vae/0002_digits\weights/weights-019-45.87.h5
#
# Epoch 00019: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 20/200
# 60000/60000 [==============================] - 55s 911us/step - loss: 45.8161 - vae_r_loss: 40.7502 - vae_kl_loss: 5.0659
#
# Epoch 00020: saving model to run/vae/0002_digits\weights/weights-020-45.82.h5
#
# Epoch 00020: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 21/200
# 60000/60000 [==============================] - 55s 915us/step - loss: 45.7742 - vae_r_loss: 40.6907 - vae_kl_loss: 5.0834
#
# Epoch 00021: saving model to run/vae/0002_digits\weights/weights-021-45.77.h5
#
# Epoch 00021: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 22/200
# 60000/60000 [==============================] - 56s 931us/step - loss: 45.6771 - vae_r_loss: 40.5757 - vae_kl_loss: 5.1014s - loss: 45.6638 - vae_r_los
#
# Epoch 00022: saving model to run/vae/0002_digits\weights/weights-022-45.68.h5
#
# Epoch 00022: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 23/200
# 60000/60000 [==============================] - 56s 933us/step - loss: 45.6279 - vae_r_loss: 40.5396 - vae_kl_loss: 5.0883s - loss: 45.6362 - vae_r - ETA: 0s - loss: 45.6294 - vae_r_loss:
#
# Epoch 00023: saving model to run/vae/0002_digits\weights/weights-023-45.63.h5
#
# Epoch 00023: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 24/200
# 60000/60000 [==============================] - 55s 915us/step - loss: 45.5822 - vae_r_loss: 40.4695 - vae_kl_loss: 5.1127
#
# Epoch 00024: saving model to run/vae/0002_digits\weights/weights-024-45.58.h5
#
# Epoch 00024: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 25/200
# 60000/60000 [==============================] - 55s 909us/step - loss: 45.4852 - vae_r_loss: 40.3644 - vae_kl_loss: 5.1208
#
# Epoch 00025: saving model to run/vae/0002_digits\weights/weights-025-45.49.h5
#
# Epoch 00025: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 26/200
# 60000/60000 [==============================] - 55s 914us/step - loss: 45.4560 - vae_r_loss: 40.3239 - vae_kl_loss: 5.1321  - ETA: 8s - loss: 45.4547 - vae_r_loss: 40.31
#
# Epoch 00026: saving model to run/vae/0002_digits\weights/weights-026-45.46.h5
#
# Epoch 00026: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 27/200
# 60000/60000 [==============================] - 55s 917us/step - loss: 45.3925 - vae_r_loss: 40.2630 - vae_kl_loss: 5.1295
#
# Epoch 00027: saving model to run/vae/0002_digits\weights/weights-027-45.39.h5
#
# Epoch 00027: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 28/200
# 60000/60000 [==============================] - 56s 928us/step - loss: 45.3676 - vae_r_loss: 40.2198 - vae_kl_loss: 5.1477
#
# Epoch 00028: saving model to run/vae/0002_digits\weights/weights-028-45.37.h5
#
# Epoch 00028: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 29/200
# 60000/60000 [==============================] - 56s 939us/step - loss: 45.3146 - vae_r_loss: 40.1710 - vae_kl_loss: 5.1436
#
# Epoch 00029: saving model to run/vae/0002_digits\weights/weights-029-45.31.h5
#
# Epoch 00029: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 30/200
# 60000/60000 [==============================] - 56s 940us/step - loss: 45.2799 - vae_r_loss: 40.1268 - vae_kl_loss: 5.1531
#
# Epoch 00030: saving model to run/vae/0002_digits\weights/weights-030-45.28.h5
#
# Epoch 00030: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 31/200
# 60000/60000 [==============================] - 56s 938us/step - loss: 45.2072 - vae_r_loss: 40.0404 - vae_kl_loss: 5.1668
#
# Epoch 00031: saving model to run/vae/0002_digits\weights/weights-031-45.21.h5
#
# Epoch 00031: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 32/200
# 60000/60000 [==============================] - 56s 935us/step - loss: 45.1694 - vae_r_loss: 39.9966 - vae_kl_loss: 5.1728
#
# Epoch 00032: saving model to run/vae/0002_digits\weights/weights-032-45.17.h5
#
# Epoch 00032: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 33/200
# 60000/60000 [==============================] - 56s 936us/step - loss: 45.1511 - vae_r_loss: 39.9678 - vae_kl_loss: 5.1832s - los
#
# Epoch 00033: saving model to run/vae/0002_digits\weights/weights-033-45.15.h5
#
# Epoch 00033: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 34/200
# 60000/60000 [==============================] - 56s 941us/step - loss: 45.0956 - vae_r_loss: 39.9168 - vae_kl_loss: 5.1788s - loss:
#
# Epoch 00034: saving model to run/vae/0002_digits\weights/weights-034-45.10.h5
#
# Epoch 00034: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 35/200
# 60000/60000 [==============================] - 56s 935us/step - loss: 45.0763 - vae_r_loss: 39.8910 - vae_kl_loss: 5.1853
#
# Epoch 00035: saving model to run/vae/0002_digits\weights/weights-035-45.08.h5
#
# Epoch 00035: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 36/200
# 60000/60000 [==============================] - 56s 940us/step - loss: 45.0711 - vae_r_loss: 39.8683 - vae_kl_loss: 5.2028
#
# Epoch 00036: saving model to run/vae/0002_digits\weights/weights-036-45.07.h5
#
# Epoch 00036: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 37/200
# 60000/60000 [==============================] - 56s 940us/step - loss: 45.0292 - vae_r_loss: 39.8485 - vae_kl_loss: 5.1807
#
# Epoch 00037: saving model to run/vae/0002_digits\weights/weights-037-45.03.h5
#
# Epoch 00037: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 38/200
# 60000/60000 [==============================] - ETA: 0s - loss: 44.9939 - vae_r_loss: 39.8000 - vae_kl_loss: 5.1939 ETA: 0s - loss: 44.9852 - vae_r_loss: 39.7906 - vae_kl_ - 56s 935us/step - loss: 44.9984 - vae_r_loss: 39.8047 - vae_kl_loss: 5.1936
#
# Epoch 00038: saving model to run/vae/0002_digits\weights/weights-038-45.00.h5
#
# Epoch 00038: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 39/200
# 60000/60000 [==============================] - 57s 943us/step - loss: 44.9569 - vae_r_loss: 39.7628 - vae_kl_loss: 5.1941
#
# Epoch 00039: saving model to run/vae/0002_digits\weights/weights-039-44.96.h5
#
# Epoch 00039: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 40/200
# 60000/60000 [==============================] - 56s 925us/step - loss: 44.9028 - vae_r_loss: 39.6988 - vae_kl_loss: 5.2041
#
# Epoch 00040: saving model to run/vae/0002_digits\weights/weights-040-44.90.h5
#
# Epoch 00040: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 41/200
# 60000/60000 [==============================] - 55s 921us/step - loss: 44.8772 - vae_r_loss: 39.6706 - vae_kl_loss: 5.2067
#
# Epoch 00041: saving model to run/vae/0002_digits\weights/weights-041-44.88.h5
#
# Epoch 00041: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 42/200
# 60000/60000 [==============================] - 56s 927us/step - loss: 44.8609 - vae_r_loss: 39.6434 - vae_kl_loss: 5.2175
#
# Epoch 00042: saving model to run/vae/0002_digits\weights/weights-042-44.86.h5
#
# Epoch 00042: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 43/200
# 60000/60000 [==============================] - 56s 929us/step - loss: 44.8130 - vae_r_loss: 39.5794 - vae_kl_loss: 5.2335
#
# Epoch 00043: saving model to run/vae/0002_digits\weights/weights-043-44.81.h5
#
# Epoch 00043: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 44/200
# 60000/60000 [==============================] - 56s 930us/step - loss: 44.8169 - vae_r_loss: 39.5731 - vae_kl_loss: 5.2438s - loss: 44.8078 - vae_r_loss: 3 - ETA: 0s - loss: 44.8161 - vae_r_loss: 39.5719 - vae_kl_loss
#
# Epoch 00044: saving model to run/vae/0002_digits\weights/weights-044-44.82.h5
#
# Epoch 00044: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 45/200
# 60000/60000 [==============================] - 56s 938us/step - loss: 44.7715 - vae_r_loss: 39.5468 - vae_kl_loss: 5.2247
#
# Epoch 00045: saving model to run/vae/0002_digits\weights/weights-045-44.77.h5
#
# Epoch 00045: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 46/200
# 60000/60000 [==============================] - 56s 938us/step - loss: 44.7405 - vae_r_loss: 39.5075 - vae_kl_loss: 5.2331s - loss: 4
#
# Epoch 00046: saving model to run/vae/0002_digits\weights/weights-046-44.74.h5
#
# Epoch 00046: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 47/200
# 60000/60000 [==============================] - 57s 947us/step - loss: 44.7166 - vae_r_loss: 39.4816 - vae_kl_loss: 5.2350
#
# Epoch 00047: saving model to run/vae/0002_digits\weights/weights-047-44.72.h5
#
# Epoch 00047: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 48/200
# 60000/60000 [==============================] - 56s 927us/step - loss: 44.7059 - vae_r_loss: 39.4694 - vae_kl_loss: 5.2365
#
# Epoch 00048: saving model to run/vae/0002_digits\weights/weights-048-44.71.h5
#
# Epoch 00048: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 49/200
# 60000/60000 [==============================] - 56s 926us/step - loss: 44.6711 - vae_r_loss: 39.4302 - vae_kl_loss: 5.2408
#
# Epoch 00049: saving model to run/vae/0002_digits\weights/weights-049-44.67.h5
#
# Epoch 00049: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 50/200
# 60000/60000 [==============================] - 57s 949us/step - loss: 44.6335 - vae_r_loss: 39.3884 - vae_kl_loss: 5.2451
#
# Epoch 00050: saving model to run/vae/0002_digits\weights/weights-050-44.63.h5
#
# Epoch 00050: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 51/200
# 60000/60000 [==============================] - 35603s 593ms/step - loss: 44.6331 - vae_r_loss: 39.3772 - vae_kl_loss: 5.2559
#
# Epoch 00051: saving model to run/vae/0002_digits\weights/weights-051-44.63.h5
#
# Epoch 00051: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 52/200
# 60000/60000 [==============================] - 59s 984us/step - loss: 44.6197 - vae_r_loss: 39.3547 - vae_kl_loss: 5.2650
#
# Epoch 00052: saving model to run/vae/0002_digits\weights/weights-052-44.62.h5
#
# Epoch 00052: saving model to run/vae/0002_digits\weights/weights.h5
# Epoch 53/200
# 22496/60000 [==========>...................] - ETA: 35s - loss: 44.4982 - vae_r_loss: 39.2570 - vae_kl_loss: 5.2412
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-a0cdb3ff19b5> in <module>
#       5     , run_folder = RUN_FOLDER
#       6     , print_every_n_batches = PRINT_EVERY_N_BATCHES
# ----> 7     , initial_epoch = INITIAL_EPOCH
#       8 )
#
# D:\ImageProssecing\BookSample\GDL_code-master\models\VAE.py in train(self, x_train, batch_size, epochs, run_folder, print_every_n_batches, initial_epoch, lr_decay)
#     200             , epochs = epochs
#     201             , initial_epoch = initial_epoch
# --> 202             , callbacks = callbacks_list
#     203         )
#     204
#
# D:\anaconda3\envs\generative\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# D:\anaconda3\envs\generative\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# D:\anaconda3\envs\generative\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# D:\anaconda3\envs\generative\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# D:\anaconda3\envs\generative\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1456         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1457                                                self._handle, args,
# -> 1458                                                run_metadata_ptr)
#    1459         if run_metadata:
#    1460           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# Please consider that the whole process has been run on a personal computer. So, after 24 hours of running, it got to epoch 53 and for the sake of the health of the system.the process has been stopped.

# %% [markdown]
# # VAE Analysis

# %% [markdown]
# ## imports

# %%
from utils.loaders import  load_model

# %% [markdown]
# ## architecture

# %%
vae = load_model(VariationalAutoencoder, RUN_FOLDER)

# %% [markdown]
# ## reconstructing original paintings

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

z_points = vae.encoder.predict(example_images)

reconst_images = vae.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+1)
    sub.axis('off')
    sub.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=sub.transAxes)
   #represents orginal handwritten         
    sub.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    sub = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    sub.axis('off')
    #represents constructed handwritten     
    sub.imshow(img, cmap='gray_r')
   #As you may notice the constructed images are way better than previous architecture(AE.py)

# %% [markdown]
# ## Mr N. Coder's wall

# %%
#the previous plot has shown the reconstruction by showing 10 points and as you can see the results were good.
#but when we choose 5000 there are a few mistakes in reconstructing the image.
#As you may notice when there are a lot of points there might be close together or overlapped that's the reason for bad reconstructing.
n_to_show = 5000
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)

plt.show()

# %% [markdown]
# ### The new generated art exhibition

# %%
figsize = 8
plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)


grid_size = 15
grid_depth = 2
figsize = 15

x = np.random.normal(size = grid_size * grid_depth)
y = np.random.normal(size = grid_size * grid_depth)

z_grid = np.array(list(zip(x, y)))
reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=8, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
fig_height = 7
fig_width = 15

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)
p_points = norm.cdf(z_points)

fig = plt.figure(figsize=(fig_width, fig_height))

ax = fig.add_subplot(1, 2, 1)
plot_1 = ax.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar(plot_1)

ax = fig.add_subplot(1, 2, 2)
plot_2 = ax.scatter(p_points[:, 0] , p_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=5)

#this right plot shows that each color is approximately equally represented
#As you can see each color represents a specific number but keep in mind that there is no label in the data.
#the VAE has learned the various forms of digits by itself in order to help minimize reconstruction loss.
plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = vae.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

x = norm.ppf(np.linspace(0.01, 0.99, grid_size))
y = norm.ppf(np.linspace(0.01, 0.99, grid_size))
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = vae.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=2)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
    #As you can see the point which is in the border (In a place there is one color or two)have better quality rather than
    #the points inside(In a place where numbers are close together like 9 and 8)
